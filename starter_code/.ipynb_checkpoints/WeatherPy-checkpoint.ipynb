# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# !pip install citipy
# !jupyter nbextension enable --py --sys-prefix citipy
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
# Requirement already satisfied: citipy in c:\users\megam\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\megam\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)
# Traceback (most recent call last):
#   File "C:\Users\megam\Anaconda3\envs\PythonData\Scripts\jupyter-nbextension-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\megam\Anaconda3\envs\PythonData\lib\site-packages\jupyter_core\application.py", line 267, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "C:\Users\megam\Anaconda3\envs\PythonData\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\megam\Anaconda3\envs\PythonData\lib\site-packages\notebook\nbextensions.py", line 988, in start
#     super(NBExtensionApp, self).start()
#   File "C:\Users\megam\Anaconda3\envs\PythonData\lib\site-packages\jupyter_core\application.py", line 256, in start
#     self.subapp.start()
#   File "C:\Users\megam\Anaconda3\envs\PythonData\lib\site-packages\notebook\nbextensions.py", line 896, in start
#     self.toggle_nbextension_python(self.extra_args[0])
#   File "C:\Users\megam\Anaconda3\envs\PythonData\lib\site-packages\notebook\nbextensions.py", line 872, in toggle_nbextension_python
#     logger=self.log)
#   File "C:\Users\megam\Anaconda3\envs\PythonData\lib\site-packages\notebook\nbextensions.py", line 483, in enable_nbextension_python
#     logger=logger)
#   File "C:\Users\megam\Anaconda3\envs\PythonData\lib\site-packages\notebook\nbextensions.py", line 380, in _set_nbextension_state_python
#     m, nbexts = _get_nbextension_metadata(module)
#   File "C:\Users\megam\Anaconda3\envs\PythonData\lib\site-packages\notebook\nbextensions.py", line 1125, in _get_nbextension_metadata
#     'it is missing the `_jupyter_nbextension_paths()` method.'.format(module))
# KeyError: 'The Python module citipy is not a valid nbextension, it is missing the `_jupyter_nbextension_paths()` method.'

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import? API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
cities

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

cities_list = pd.DataFrame(cities)

cities_df = pd.DataFrame(columns = ['City', 'Cloudiness', 'Country', 'Humidity', 'Lat', 'Lon', 'Max Temp', 'Wind Speed']) 

cities_df
# cities_df["Cloudiness"] = []
# cities_df["Country"] = []
# cities_df["Humidity"] = []
# cities_df["Lat"] = []
# cities_df["Lon"] = []
# cities_df["Max Temp"] = []
# cities_df["Wind Speed"] = []

        
# Print the city count to confirm sufficient count
# len(cities)
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Humidity, Lat, Lon, Max Temp, Wind Speed]
# Index: []

# %%
# cities_list

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
### Find out how to retrieve specific weather info FOR WEATHERMAPY
# base_url = "http://api.openweathermap.org/?"
# params = {
#     "q": cities,
#     "APPID": api_key,
# }

# request = requests.get(base_url, params).json()


######

# use iterrows to iterate through pandas dataframe
for index, row in cities_list.iterrows():

    random_city = np.random.choice(cities, 1)

    base_url = "http://api.openweathermap.org/data/2.5/weather?"
    params = {
        "q": random_city,
        "APPID": api_key,
    }


    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {random_city}.")
    response = requests.get(base_url, params).json()
    
#     print(json.dumps(response, indent=4))

    # extract results
#     results = response['results']
    
    try:
        print(f"Randomly found a city : {response['name']}.")
        
        cities_df.loc[index, 'City'] = response['name']
        cities_df.loc[index, 'Cloudiness'] = response['clouds']['all']
        cities_df.loc[index, 'Country'] = response['sys']['country']
        cities_df.loc[index, 'Humidity'] = response['main']['humidity']
        cities_df.loc[index, 'Lat'] = response['coord']['lat']
        cities_df.loc[index, 'Lon'] = response['coord']['lon']
        cities_df.loc[index, 'Max Temp'] = response['main']['temp_max']
        cities_df.loc[index, 'Wind Speed'] = response['wind']['speed']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 0: ['iqaluit'].
# Randomly found a city : Iqaluit.
# ------------
# Retrieving Results for Index 1: ['ginda'].
# Randomly found a city : Ginda.
# ------------
# Retrieving Results for Index 2: ['bembibre'].
# Randomly found a city : Bembibre.
# ------------
# Retrieving Results for Index 3: ['aykhal'].
# Randomly found a city : Aykhal.
# ------------
# Retrieving Results for Index 4: ['prachuap khiri khan'].
# Randomly found a city : Prachuap Khiri Khan.
# ------------
# Retrieving Results for Index 5: ['kununurra'].
# Randomly found a city : Kununurra.
# ------------
# Retrieving Results for Index 6: ['balagansk'].
# Randomly found a city : Balagansk.
# ------------
# Retrieving Results for Index 7: ['saint anthony'].
# Randomly found a city : Saint Anthony.
# ------------
# Retrieving Results for Index 8: ['bolungarvik'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 9: ['chuy'].
# Randomly found a city : Chuy.
# ------------
# Retrieving Results for Index 10: ['atuona'].
# Randomly found a city : Atuona.
# ------------
# Retrieving Results for Index 11: ['pringsewu'].
# Randomly found a city : Pringsewu.
# ------------
# Retrieving Results for Index 12: ['kupang'].
# Randomly found a city : Kupang.
# ------------
# Retrieving Results for Index 13: ['lagoa'].
# Randomly found a city : Lagoa.
# ------------
# Retrieving Results for Index 14: ['tsihombe'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 15: ['pahrump'].
# Randomly found a city : Pahrump.
# ------------
# Retrieving Results for Index 16: ['ust-kamchatsk'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 17: ['kapaa'].
# Randomly found a city : Kapaa.
# ------------
# Retrieving Results for Index 18: ['tongsa'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 19: ['landshut'].
# Randomly found a city : Landshut.
# ------------
# Retrieving Results for Index 20: ['nemuro'].
# Randomly found a city : Nemuro.
# ------------
# Retrieving Results for Index 21: ['amahai'].
# Randomly found a city : Amahai.
# ------------
# Retrieving Results for Index 22: ['provideniya'].
# Randomly found a city : Provideniya.
# ------------
# Retrieving Results for Index 23: ['khokhlovo'].
# Randomly found a city : Khokhlovo.
# ------------
# Retrieving Results for Index 24: ['belushya guba'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 25: ['hilo'].
# Randomly found a city : Hilo.
# ------------
# Retrieving Results for Index 26: ['satitoa'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 27: ['jumla'].
# Randomly found a city : Jumla.
# ------------
# Retrieving Results for Index 28: ['tuktoyaktuk'].
# Randomly found a city : Tuktoyaktuk.
# ------------
# Retrieving Results for Index 29: ['geraldton'].
# Randomly found a city : Geraldton.
# ------------
# Retrieving Results for Index 30: ['kamenka'].
# Randomly found a city : Kamenka.
# ------------
# Retrieving Results for Index 31: ['humberto de campos'].
# Randomly found a city : Humberto de Campos.
# ------------
# Retrieving Results for Index 32: ['ponazyrevo'].
# Randomly found a city : Ponazyrevo.
# ------------
# Retrieving Results for Index 33: ['te anau'].
# Randomly found a city : Te Anau.
# ------------
# Retrieving Results for Index 34: ['iracoubo'].
# Randomly found a city : Iracoubo.
# ------------
# Retrieving Results for Index 35: ['geresk'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 36: ['te anau'].
# Randomly found a city : Te Anau.
# ------------
# Retrieving Results for Index 37: ['nizhnyaya salda'].
# Randomly found a city : Nizhnyaya Salda.
# ------------
# Retrieving Results for Index 38: ['avarua'].
# Randomly found a city : Avarua.
# ------------
# Retrieving Results for Index 39: ['husavik'].
# Randomly found a city : Husavik.
# ------------
# Retrieving Results for Index 40: ['luanda'].
# Randomly found a city : Luanda.
# ------------
# Retrieving Results for Index 41: ['saint george'].
# Randomly found a city : Saint George.
# ------------
# Retrieving Results for Index 42: ['raudeberg'].
# Randomly found a city : Raudeberg.
# ------------
# Retrieving Results for Index 43: ['shitanjing'].
# Randomly found a city : Shitanjing.
# ------------
# Retrieving Results for Index 44: ['abakaliki'].
# Randomly found a city : Abakaliki.
# ------------
# Retrieving Results for Index 45: ['voznesenskaya'].
# Randomly found a city : Voznesenskaya.
# ------------
# Retrieving Results for Index 46: ['atar'].
# Randomly found a city : Atar.
# ------------
# Retrieving Results for Index 47: ['victoria'].
# Randomly found a city : Victoria.
# ------------
# Retrieving Results for Index 48: ['bacolod'].
# Randomly found a city : Bacolod.
# ------------
# Retrieving Results for Index 49: ['vila velha'].
# Randomly found a city : Vila Velha.
# ------------
# Retrieving Results for Index 50: ['rundu'].
# Randomly found a city : Rundu.
# ------------
# Retrieving Results for Index 51: ['cascais'].
# Randomly found a city : Cascais.
# ------------
# Retrieving Results for Index 52: ['sao gabriel da cachoeira'].
# Randomly found a city : Sao Gabriel da Cachoeira.
# ------------
# Retrieving Results for Index 53: ['nizhnyaya salda'].
# Randomly found a city : Nizhnyaya Salda.
# ------------
# Retrieving Results for Index 54: ['vysokogornyy'].
# Randomly found a city : Vysokogornyy.
# ------------
# Retrieving Results for Index 55: ['nemuro'].
# Randomly found a city : Nemuro.
# ------------
# Retrieving Results for Index 56: ['barrow'].
# Randomly found a city : Barrow.
# ------------
# Retrieving Results for Index 57: ['beringovskiy'].
# Randomly found a city : Beringovskiy.
# ------------
# Retrieving Results for Index 58: ['hirado'].
# Randomly found a city : Hirado.
# ------------
# Retrieving Results for Index 59: ['iracoubo'].
# Randomly found a city : Iracoubo.
# ------------
# Retrieving Results for Index 60: ['busselton'].
# Randomly found a city : Busselton.
# ------------
# Retrieving Results for Index 61: ['guerrero negro'].
# Randomly found a city : Guerrero Negro.
# ------------
# Retrieving Results for Index 62: ['leningradskiy'].
# Randomly found a city : Leningradskiy.
# ------------
# Retrieving Results for Index 63: ['bacolod'].
# Randomly found a city : Bacolod.
# ------------
# Retrieving Results for Index 64: ['great malvern'].
# Randomly found a city : Great Malvern.
# ------------
# Retrieving Results for Index 65: ['margate'].
# Randomly found a city : Margate.
# ------------
# Retrieving Results for Index 66: ['akyab'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 67: ['bluff'].
# Randomly found a city : Bluff.
# ------------
# Retrieving Results for Index 68: ['tura'].
# Randomly found a city : Tura.
# ------------
# Retrieving Results for Index 69: ['whitianga'].
# Randomly found a city : Whitianga.
# ------------
# Retrieving Results for Index 70: ['hermanus'].
# Randomly found a city : Hermanus.
# ------------
# Retrieving Results for Index 71: ['north platte'].
# Randomly found a city : North Platte.
# ------------
# Retrieving Results for Index 72: ['juegang'].
# Randomly found a city : Juegang.
# ------------
# Retrieving Results for Index 73: ['nikolskoye'].
# Randomly found a city : Nikolskoye.
# ------------
# Retrieving Results for Index 74: ['palmer'].
# Randomly found a city : Palmer.
# ------------
# Retrieving Results for Index 75: ['bembibre'].
# Randomly found a city : Bembibre.
# ------------
# Retrieving Results for Index 76: ['muros'].
# Randomly found a city : Muros.
# ------------
# Retrieving Results for Index 77: ['pisco'].
# Randomly found a city : Pisco.
# ------------
# Retrieving Results for Index 78: ['yanchukan'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 79: ['mahebourg'].
# Randomly found a city : Mahebourg.
# ------------
# Retrieving Results for Index 80: ['tiznit'].
# Randomly found a city : Tiznit.
# ------------
# Retrieving Results for Index 81: ['ginda'].
# Randomly found a city : Ginda.
# ------------
# Retrieving Results for Index 82: ['orange walk'].
# Randomly found a city : Orange Walk.
# ------------
# Retrieving Results for Index 83: ['shintomi'].
# Randomly found a city : Shintomi.
# ------------
# Retrieving Results for Index 84: ['mandurah'].
# Randomly found a city : Mandurah.
# ------------
# Retrieving Results for Index 85: ['kissidougou'].
# Randomly found a city : Kissidougou.
# ------------
# Retrieving Results for Index 86: ['emerald'].
# Randomly found a city : Emerald.
# ------------
# Retrieving Results for Index 87: ['dalbandin'].
# Randomly found a city : Dalbandin.
# ------------
# Retrieving Results for Index 88: ['kovur'].
# Randomly found a city : Kovur.
# ------------
# Retrieving Results for Index 89: ['babanusah'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 90: ['urdzhar'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 91: ['azimur'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 92: ['albany'].
# Randomly found a city : Albany.
# ------------
# Retrieving Results for Index 93: ['balkanabat'].
# Randomly found a city : Balkanabat.
# ------------
# Retrieving Results for Index 94: ['paysandu'].
# Randomly found a city : Paysandu.
# ------------
# Retrieving Results for Index 95: ['magdalena'].
# Randomly found a city : Magdalena.
# ------------
# Retrieving Results for Index 96: ['ramsar'].
# Randomly found a city : Ramsar.
# ------------
# Retrieving Results for Index 97: ['kalanchak'].
# Randomly found a city : Kalanchak.
# ------------
# Retrieving Results for Index 98: ['ormara'].
# Randomly found a city : Ormara.
# ------------
# Retrieving Results for Index 99: ['port macquarie'].
# Randomly found a city : Port Macquarie.
# ------------
# Retrieving Results for Index 100: ['soyo'].
# Randomly found a city : Soyo.
# ------------
# Retrieving Results for Index 101: ['amderma'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 102: ['ostrovnoy'].
# Randomly found a city : Ostrovnoy.
# ------------
# Retrieving Results for Index 103: ['le mars'].
# Randomly found a city : Le Mars.
# ------------
# Retrieving Results for Index 104: ['turbat'].
# Randomly found a city : Turbat.
# ------------
# Retrieving Results for Index 105: ['kutum'].
# Randomly found a city : Kutum.
# ------------
# Retrieving Results for Index 106: ['kushima'].
# Randomly found a city : Kushima.
# ------------
# Retrieving Results for Index 107: ['sao felix do xingu'].
# Randomly found a city : Sao Felix do Xingu.
# ------------
# Retrieving Results for Index 108: ['bluff'].
# Randomly found a city : Bluff.
# ------------
# Retrieving Results for Index 109: ['kuliyapitiya'].
# Randomly found a city : Kuliyapitiya.
# ------------
# Retrieving Results for Index 110: ['cap malheureux'].
# Randomly found a city : Cap Malheureux.
# ------------
# Retrieving Results for Index 111: ['karla'].
# Randomly found a city : Karla.
# ------------
# Retrieving Results for Index 112: ['ponazyrevo'].
# Randomly found a city : Ponazyrevo.
# ------------
# Retrieving Results for Index 113: ['baruun-urt'].
# Randomly found a city : Baruun-Urt.
# ------------
# Retrieving Results for Index 114: ['kirando'].
# Randomly found a city : Kirando.
# ------------
# Retrieving Results for Index 115: ['kristiinankaupunki'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 116: ['grindavik'].
# Randomly found a city : Grindavik.
# ------------
# Retrieving Results for Index 117: ['kodiak'].
# Randomly found a city : Kodiak.
# ------------
# Retrieving Results for Index 118: ['paysandu'].
# Randomly found a city : Paysandu.
# ------------
# Retrieving Results for Index 119: ['luau'].
# Randomly found a city : Luau.
# ------------
# Retrieving Results for Index 120: ['khatanga'].
# Randomly found a city : Khatanga.
# ------------
# Retrieving Results for Index 121: ['dikson'].
# Randomly found a city : Dikson.
# ------------
# Retrieving Results for Index 122: ['zhanatas'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 123: ['hobart'].
# Randomly found a city : Hobart.
# ------------
# Retrieving Results for Index 124: ['kapaa'].
# Randomly found a city : Kapaa.
# ------------
# Retrieving Results for Index 125: ['nizhnyaya salda'].
# Randomly found a city : Nizhnyaya Salda.
# ------------
# Retrieving Results for Index 126: ['port keats'].
# Randomly found a city : Port Keats.
# ------------
# Retrieving Results for Index 127: ['constitucion'].
# Randomly found a city : Constitucion.
# ------------
# Retrieving Results for Index 128: ['kirksville'].
# Randomly found a city : Kirksville.
# ------------
# Retrieving Results for Index 129: ['chicama'].
# Randomly found a city : Chicama.
# ------------
# Retrieving Results for Index 130: ['kodinsk'].
# Randomly found a city : Kodinsk.
# ------------
# Retrieving Results for Index 131: ['te anau'].
# Randomly found a city : Te Anau.
# ------------
# Retrieving Results for Index 132: ['sentyabrskiy'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 133: ['cape town'].
# Randomly found a city : Cape Town.
# ------------
# Retrieving Results for Index 134: ['longonjo'].
# Randomly found a city : Longonjo.
# ------------
# Retrieving Results for Index 135: ['port macquarie'].
# Randomly found a city : Port Macquarie.
# ------------
# Retrieving Results for Index 136: ['nikolskoye'].
# Randomly found a city : Nikolskoye.
# ------------
# Retrieving Results for Index 137: ['tiznit'].
# Randomly found a city : Tiznit.
# ------------
# Retrieving Results for Index 138: ['juneau'].
# Randomly found a city : Juneau.
# ------------
# Retrieving Results for Index 139: ['yelniki'].
# Randomly found a city : Yelniki.
# ------------
# Retrieving Results for Index 140: ['mahebourg'].
# Randomly found a city : Mahebourg.
# ------------
# Retrieving Results for Index 141: ['killarney'].
# Randomly found a city : Killarney.
# ------------
# Retrieving Results for Index 142: ['boden'].
# Randomly found a city : Boden.
# ------------
# Retrieving Results for Index 143: ['kargopol'].
# Randomly found a city : Kargopol.
# ------------
# Retrieving Results for Index 144: ['ponta do sol'].
# Randomly found a city : Ponta do Sol.
# ------------
# Retrieving Results for Index 145: ['green river'].
# Randomly found a city : Green River.
# ------------
# Retrieving Results for Index 146: ['castro'].
# Randomly found a city : Castro.
# ------------
# Retrieving Results for Index 147: ['syracuse'].
# Randomly found a city : Syracuse.
# ------------
# Retrieving Results for Index 148: ['glasgow'].
# Randomly found a city : Glasgow.
# ------------
# Retrieving Results for Index 149: ['tezu'].
# Randomly found a city : Tezu.
# ------------
# Retrieving Results for Index 150: ['preobrazheniye'].
# Randomly found a city : Preobrazheniye.
# ------------
# Retrieving Results for Index 151: ['manta'].
# Randomly found a city : Manta.
# ------------
# Retrieving Results for Index 152: ['port alfred'].
# Randomly found a city : Port Alfred.
# ------------
# Retrieving Results for Index 153: ['fayaoue'].
# Randomly found a city : Fayaoue.
# ------------
# Retrieving Results for Index 154: ['maumere'].
# Randomly found a city : Maumere.
# ------------
# Retrieving Results for Index 155: ['leningradskiy'].
# Randomly found a city : Leningradskiy.
# ------------
# Retrieving Results for Index 156: ['hamilton'].
# Randomly found a city : Hamilton.
# ------------
# Retrieving Results for Index 157: ['springfield'].
# Randomly found a city : Springfield.
# ------------
# Retrieving Results for Index 158: ['geraldton'].
# Randomly found a city : Geraldton.
# ------------
# Retrieving Results for Index 159: ['salalah'].
# Randomly found a city : Salalah.
# ------------
# Retrieving Results for Index 160: ['atambua'].
# Randomly found a city : Atambua.
# ------------
# Retrieving Results for Index 161: ['banjarmasin'].
# Randomly found a city : Banjarmasin.
# ------------
# Retrieving Results for Index 162: ['kununurra'].
# Randomly found a city : Kununurra.
# ------------
# Retrieving Results for Index 163: ['naze'].
# Randomly found a city : Naze.
# ------------
# Retrieving Results for Index 164: ['thompson'].
# Randomly found a city : Thompson.
# ------------
# Retrieving Results for Index 165: ['provideniya'].
# Randomly found a city : Provideniya.
# ------------
# Retrieving Results for Index 166: ['komsomolskiy'].
# Randomly found a city : Komsomolskiy.
# ------------
# Retrieving Results for Index 167: ['russell'].
# Randomly found a city : Russell.
# ------------
# Retrieving Results for Index 168: ['gat'].
# Randomly found a city : Gat.
# ------------
# Retrieving Results for Index 169: ['barcelona'].
# Randomly found a city : Barcelona.
# ------------
# Retrieving Results for Index 170: ['cassilandia'].
# Randomly found a city : Cassilandia.
# ------------
# Retrieving Results for Index 171: ['hermanus'].
# Randomly found a city : Hermanus.
# ------------
# Retrieving Results for Index 172: ['flin flon'].
# Randomly found a city : Flin Flon.
# ------------
# Retrieving Results for Index 173: ['komsomolskiy'].
# Randomly found a city : Komsomolskiy.
# ------------
# Retrieving Results for Index 174: ['barcelona'].
# Randomly found a city : Barcelona.
# ------------
# Retrieving Results for Index 175: ['nibbar'].
# Randomly found a city : Nibbar.
# ------------
# Retrieving Results for Index 176: ['virginia beach'].
# Randomly found a city : Virginia Beach.
# ------------
# Retrieving Results for Index 177: ['illoqqortoormiut'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 178: ['evensk'].
# Randomly found a city : Evensk.
# ------------
# Retrieving Results for Index 179: ['minas de barroteran'].
# Randomly found a city : Minas de Barroteran.
# ------------
# Retrieving Results for Index 180: ['hun'].
# Randomly found a city : Hun.
# ------------
# Retrieving Results for Index 181: ['coihaique'].
# Randomly found a city : Coihaique.
# ------------
# Retrieving Results for Index 182: ['sentyabrskiy'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 183: ['khorramshahr'].
# Randomly found a city : Khorramshahr.
# ------------
# Retrieving Results for Index 184: ['chivacoa'].
# Randomly found a city : Chivacoa.
# ------------
# Retrieving Results for Index 185: ['lerwick'].
# Randomly found a city : Lerwick.
# ------------
# Retrieving Results for Index 186: ['visby'].
# Randomly found a city : Visby.
# ------------
# Retrieving Results for Index 187: ['constitucion'].
# Randomly found a city : Constitucion.
# ------------
# Retrieving Results for Index 188: ['labuhan'].
# Randomly found a city : Labuhan.
# ------------
# Retrieving Results for Index 189: ['stolin'].
# Randomly found a city : Stolin.
# ------------
# Retrieving Results for Index 190: ['mackay'].
# Randomly found a city : Mackay.
# ------------
# Retrieving Results for Index 191: ['port-gentil'].
# Randomly found a city : Port-Gentil.
# ------------
# Retrieving Results for Index 192: ['assiniboia'].
# Randomly found a city : Assiniboia.
# ------------
# Retrieving Results for Index 193: ['mehran'].
# Randomly found a city : Mehran.
# ------------
# Retrieving Results for Index 194: ['iringa'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 195: ['north platte'].
# Randomly found a city : North Platte.
# ------------
# Retrieving Results for Index 196: ['bacolod'].
# Randomly found a city : Bacolod.
# ------------
# Retrieving Results for Index 197: ['bembibre'].
# Randomly found a city : Bembibre.
# ------------
# Retrieving Results for Index 198: ['saint-pierre'].
# Randomly found a city : Saint-Pierre.
# ------------
# Retrieving Results for Index 199: ['concarneau'].
# Randomly found a city : Concarneau.
# ------------
# Retrieving Results for Index 200: ['voznesenskaya'].
# Randomly found a city : Voznesenskaya.
# ------------
# Retrieving Results for Index 201: ['chokurdakh'].
# Randomly found a city : Chokurdakh.
# ------------
# Retrieving Results for Index 202: ['yulara'].
# Randomly found a city : Yulara.
# ------------
# Retrieving Results for Index 203: ['soyo'].
# Randomly found a city : Soyo.
# ------------
# Retrieving Results for Index 204: ['sao miguel do araguaia'].
# Randomly found a city : Sao Miguel do Araguaia.
# ------------
# Retrieving Results for Index 205: ['meyungs'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 206: ['kimberley'].
# Randomly found a city : Kimberley.
# ------------
# Retrieving Results for Index 207: ['yellowknife'].
# Randomly found a city : Yellowknife.
# ------------
# Retrieving Results for Index 208: ['stolin'].
# Randomly found a city : Stolin.
# ------------
# Retrieving Results for Index 209: ['posse'].
# Randomly found a city : Posse.
# ------------
# Retrieving Results for Index 210: ['skagastrond'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 211: ['grindavik'].
# Randomly found a city : Grindavik.
# ------------
# Retrieving Results for Index 212: ['ballina'].
# Randomly found a city : Ballina.
# ------------
# Retrieving Results for Index 213: ['kushmurun'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 214: ['santa cruz'].
# Randomly found a city : Santa Cruz.
# ------------
# Retrieving Results for Index 215: ['anadyr'].
# Randomly found a city : Anadyr.
# ------------
# Retrieving Results for Index 216: ['marsh harbour'].
# Randomly found a city : Marsh Harbour.
# ------------
# Retrieving Results for Index 217: ['quibdo'].
# Randomly found a city : Quibdo.
# ------------
# Retrieving Results for Index 218: ['kutum'].
# Randomly found a city : Kutum.
# ------------
# Retrieving Results for Index 219: ['huatulco'].
# Randomly found a city : Huatulco.
# ------------
# Retrieving Results for Index 220: ['flin flon'].
# Randomly found a city : Flin Flon.
# ------------
# Retrieving Results for Index 221: ['kamenskoye'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 222: ['menongue'].
# Randomly found a city : Menongue.
# ------------
# Retrieving Results for Index 223: ['hanzhong'].
# Randomly found a city : Hanzhong.
# ------------
# Retrieving Results for Index 224: ['alihe'].
# Randomly found a city : Alihe.
# ------------
# Retrieving Results for Index 225: ['hamilton'].
# Randomly found a city : Hamilton.
# ------------
# Retrieving Results for Index 226: ['iqaluit'].
# Randomly found a city : Iqaluit.
# ------------
# Retrieving Results for Index 227: ['baruun-urt'].
# Randomly found a city : Baruun-Urt.
# ------------
# Retrieving Results for Index 228: ['georgetown'].
# Randomly found a city : Georgetown.
# ------------
# Retrieving Results for Index 229: ['charagua'].
# Randomly found a city : Charagua.
# ------------
# Retrieving Results for Index 230: ['qixingtai'].
# Randomly found a city : Qixingtai.
# ------------
# Retrieving Results for Index 231: ['maceio'].
# Randomly found a city : Maceio.
# ------------
# Retrieving Results for Index 232: ['tasbuget'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 233: ['samalaeulu'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 234: ['sungaipenuh'].
# Randomly found a city : Sungaipenuh.
# ------------
# Retrieving Results for Index 235: ['barentsburg'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 236: ['oriximina'].
# Randomly found a city : Oriximina.
# ------------
# Retrieving Results for Index 237: ['vila'].
# Randomly found a city : Vila.
# ------------
# Retrieving Results for Index 238: ['ust-maya'].
# Randomly found a city : Ust-Maya.
# ------------
# Retrieving Results for Index 239: ['cabo san lucas'].
# Randomly found a city : Cabo San Lucas.
# ------------
# Retrieving Results for Index 240: ['durres'].
# Randomly found a city : Durres.
# ------------
# Retrieving Results for Index 241: ['nouadhibou'].
# Randomly found a city : Nouadhibou.
# ------------
# Retrieving Results for Index 242: ['omsukchan'].
# Randomly found a city : Omsukchan.
# ------------
# Retrieving Results for Index 243: ['hereford'].
# Randomly found a city : Hereford.
# ------------
# Retrieving Results for Index 244: ['castro'].
# Randomly found a city : Castro.
# ------------
# Retrieving Results for Index 245: ['lompoc'].
# Randomly found a city : Lompoc.
# ------------
# Retrieving Results for Index 246: ['longonjo'].
# Randomly found a city : Longonjo.
# ------------
# Retrieving Results for Index 247: ['zhezkazgan'].
# Randomly found a city : Zhezkazgan.
# ------------
# Retrieving Results for Index 248: ['mataura'].
# Randomly found a city : Mataura.
# ------------
# Retrieving Results for Index 249: ['georgetown'].
# Randomly found a city : Georgetown.
# ------------
# Retrieving Results for Index 250: ['paysandu'].
# Randomly found a city : Paysandu.
# ------------
# Retrieving Results for Index 251: ['changtu'].
# Randomly found a city : Changtu.
# ------------
# Retrieving Results for Index 252: ['goundi'].
# Randomly found a city : Goundi.
# ------------
# Retrieving Results for Index 253: ['cam ranh'].
# Randomly found a city : Cam Ranh.
# ------------
# Retrieving Results for Index 254: ['khatra'].
# Randomly found a city : Khatra.
# ------------
# Retrieving Results for Index 255: ['necochea'].
# Randomly found a city : Necochea.
# ------------
# Retrieving Results for Index 256: ['bam'].
# Randomly found a city : Bam.
# ------------
# Retrieving Results for Index 257: ['tumannyy'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 258: ['la paz'].
# Randomly found a city : La Paz.
# ------------
# Retrieving Results for Index 259: ['geraldton'].
# Randomly found a city : Geraldton.
# ------------
# Retrieving Results for Index 260: ['itoman'].
# Randomly found a city : Itoman.
# ------------
# Retrieving Results for Index 261: ['klaksvik'].
# Randomly found a city : Klaksvik.
# ------------
# Retrieving Results for Index 262: ['rio grande'].
# Randomly found a city : Rio Grande.
# ------------
# Retrieving Results for Index 263: ['illoqqortoormiut'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 264: ['oriximina'].
# Randomly found a city : Oriximina.
# ------------
# Retrieving Results for Index 265: ['brae'].
# Randomly found a city : Brae.
# ------------
# Retrieving Results for Index 266: ['anadyr'].
# Randomly found a city : Anadyr.
# ------------
# Retrieving Results for Index 267: ['upernavik'].
# Randomly found a city : Upernavik.
# ------------
# Retrieving Results for Index 268: ['hay river'].
# Randomly found a city : Hay River.
# ------------
# Retrieving Results for Index 269: ['banjarmasin'].
# Randomly found a city : Banjarmasin.
# ------------
# Retrieving Results for Index 270: ['troitskoye'].
# Randomly found a city : Troitskoye.
# ------------
# Retrieving Results for Index 271: ['beringovskiy'].
# Randomly found a city : Beringovskiy.
# ------------
# Retrieving Results for Index 272: ['aswan'].
# Randomly found a city : Aswan.
# ------------
# Retrieving Results for Index 273: ['bokspits'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 274: ['norman wells'].
# Randomly found a city : Norman Wells.
# ------------
# Retrieving Results for Index 275: ['urdzhar'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 276: ['ankpa'].
# Randomly found a city : Ankpa.
# ------------
# Retrieving Results for Index 277: ['neryungri'].
# Randomly found a city : Neryungri.
# ------------
# Retrieving Results for Index 278: ['springfield'].
# Randomly found a city : Springfield.
# ------------
# Retrieving Results for Index 279: ['albany'].
# Randomly found a city : Albany.
# ------------
# Retrieving Results for Index 280: ['sadasivpet'].
# Randomly found a city : Sadasivpet.
# ------------
# Retrieving Results for Index 281: ['rawson'].
# Randomly found a city : Rawson.
# ------------
# Retrieving Results for Index 282: ['bay roberts'].
# Randomly found a city : Bay Roberts.
# ------------
# Retrieving Results for Index 283: ['moche'].
# Randomly found a city : Moche.
# ------------
# Retrieving Results for Index 284: ['hun'].
# Randomly found a city : Hun.
# ------------
# Retrieving Results for Index 285: ['moravita'].
# Randomly found a city : Moravita.
# ------------
# Retrieving Results for Index 286: ['susangerd'].
# Randomly found a city : Susangerd.
# ------------
# Retrieving Results for Index 287: ['ribeira grande'].
# Randomly found a city : Ribeira Grande.
# ------------
# Retrieving Results for Index 288: ['butaritari'].
# Randomly found a city : Butaritari.
# ------------
# Retrieving Results for Index 289: ['tateyama'].
# Randomly found a city : Tateyama.
# ------------
# Retrieving Results for Index 290: ['stornoway'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 291: ['sault sainte marie'].
# Randomly found a city : Sault Sainte Marie.
# ------------
# Retrieving Results for Index 292: ['broome'].
# Randomly found a city : Broome.
# ------------
# Retrieving Results for Index 293: ['dwarka'].
# Randomly found a city : Dwarka.
# ------------
# Retrieving Results for Index 294: ['chapais'].
# Randomly found a city : Chapais.
# ------------
# Retrieving Results for Index 295: ['punta arenas'].
# Randomly found a city : Punta Arenas.
# ------------
# Retrieving Results for Index 296: ['ilulissat'].
# Randomly found a city : Ilulissat.
# ------------
# Retrieving Results for Index 297: ['coquimbo'].
# Randomly found a city : Coquimbo.
# ------------
# Retrieving Results for Index 298: ['parrita'].
# Randomly found a city : Parrita.
# ------------
# Retrieving Results for Index 299: ['darnah'].
# Randomly found a city : Darnah.
# ------------
# Retrieving Results for Index 300: ['rundu'].
# Randomly found a city : Rundu.
# ------------
# Retrieving Results for Index 301: ['baie-comeau'].
# Randomly found a city : Baie-Comeau.
# ------------
# Retrieving Results for Index 302: ['juegang'].
# Randomly found a city : Juegang.
# ------------
# Retrieving Results for Index 303: ['sao jose da coroa grande'].
# Randomly found a city : Sao Jose da Coroa Grande.
# ------------
# Retrieving Results for Index 304: ['goundi'].
# Randomly found a city : Goundi.
# ------------
# Retrieving Results for Index 305: ['nizhnyaya salda'].
# Randomly found a city : Nizhnyaya Salda.
# ------------
# Retrieving Results for Index 306: ['bethel'].
# Randomly found a city : Bethel.
# ------------
# Retrieving Results for Index 307: ['airai'].
# Randomly found a city : Airai.
# ------------
# Retrieving Results for Index 308: ['leningradskiy'].
# Randomly found a city : Leningradskiy.
# ------------
# Retrieving Results for Index 309: ['assiniboia'].
# Randomly found a city : Assiniboia.
# ------------
# Retrieving Results for Index 310: ['bambous virieux'].
# Randomly found a city : Bambous Virieux.
# ------------
# Retrieving Results for Index 311: ['bathsheba'].
# Randomly found a city : Bathsheba.
# ------------
# Retrieving Results for Index 312: ['stornoway'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 313: ['barcelona'].
# Randomly found a city : Barcelona.
# ------------
# Retrieving Results for Index 314: ['khandyga'].
# Randomly found a city : Khandyga.
# ------------
# Retrieving Results for Index 315: ['punta arenas'].
# Randomly found a city : Punta Arenas.
# ------------
# Retrieving Results for Index 316: ['martyush'].
# Randomly found a city : Martyush.
# ------------
# Retrieving Results for Index 317: ['fayaoue'].
# Randomly found a city : Fayaoue.
# ------------
# Retrieving Results for Index 318: ['guangyuan'].
# Randomly found a city : Guangyuan.
# ------------
# Retrieving Results for Index 319: ['nizhnyaya salda'].
# Randomly found a city : Nizhnyaya Salda.
# ------------
# Retrieving Results for Index 320: ['shenzhen'].
# Randomly found a city : Shenzhen.
# ------------
# Retrieving Results for Index 321: ['arlit'].
# Randomly found a city : Arlit.
# ------------
# Retrieving Results for Index 322: ['abengourou'].
# Randomly found a city : Abengourou.
# ------------
# Retrieving Results for Index 323: ['baghdad'].
# Randomly found a city : Baghdad.
# ------------
# Retrieving Results for Index 324: ['virginia beach'].
# Randomly found a city : Virginia Beach.
# ------------
# Retrieving Results for Index 325: ['bengkulu'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 326: ['mutsamudu'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 327: ['huarmey'].
# Randomly found a city : Huarmey.
# ------------
# Retrieving Results for Index 328: ['victoria'].
# Randomly found a city : Victoria.
# ------------
# Retrieving Results for Index 329: ['beringovskiy'].
# Randomly found a city : Beringovskiy.
# ------------
# Retrieving Results for Index 330: ['coquimbo'].
# Randomly found a city : Coquimbo.
# ------------
# Retrieving Results for Index 331: ['lewisporte'].
# Randomly found a city : Lewisporte.
# ------------
# Retrieving Results for Index 332: ['maghama'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 333: ['ishigaki'].
# Randomly found a city : Ishigaki.
# ------------
# Retrieving Results for Index 334: ['sentyabrskiy'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 335: ['touros'].
# Randomly found a city : Touros.
# ------------
# Retrieving Results for Index 336: ['nizhnyaya salda'].
# Randomly found a city : Nizhnyaya Salda.
# ------------
# Retrieving Results for Index 337: ['yanchukan'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 338: ['saint-pierre'].
# Randomly found a city : Saint-Pierre.
# ------------
# Retrieving Results for Index 339: ['eagle pass'].
# Randomly found a city : Eagle Pass.
# ------------
# Retrieving Results for Index 340: ['itarema'].
# Randomly found a city : Itarema.
# ------------
# Retrieving Results for Index 341: ['longonjo'].
# Randomly found a city : Longonjo.
# ------------
# Retrieving Results for Index 342: ['le mars'].
# Randomly found a city : Le Mars.
# ------------
# Retrieving Results for Index 343: ['orotukan'].
# Randomly found a city : Orotukan.
# ------------
# Retrieving Results for Index 344: ['pahrump'].
# Randomly found a city : Pahrump.
# ------------
# Retrieving Results for Index 345: ['atambua'].
# Randomly found a city : Atambua.
# ------------
# Retrieving Results for Index 346: ['dalbandin'].
# Randomly found a city : Dalbandin.
# ------------
# Retrieving Results for Index 347: ['ankpa'].
# Randomly found a city : Ankpa.
# ------------
# Retrieving Results for Index 348: ['kargopol'].
# Randomly found a city : Kargopol.
# ------------
# Retrieving Results for Index 349: ['fayaoue'].
# Randomly found a city : Fayaoue.
# ------------
# Retrieving Results for Index 350: ['goundi'].
# Randomly found a city : Goundi.
# ------------
# Retrieving Results for Index 351: ['trincomalee'].
# Randomly found a city : Trincomalee.
# ------------
# Retrieving Results for Index 352: ['inirida'].
# Randomly found a city : Inirida.
# ------------
# Retrieving Results for Index 353: ['ruatoria'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 354: ['aklavik'].
# Randomly found a city : Aklavik.
# ------------
# Retrieving Results for Index 355: ['mount gambier'].
# Randomly found a city : Mount Gambier.
# ------------
# Retrieving Results for Index 356: ['satitoa'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 357: ['bambous virieux'].
# Randomly found a city : Bambous Virieux.
# ------------
# Retrieving Results for Index 358: ['troitskoye'].
# Randomly found a city : Troitskoye.
# ------------
# Retrieving Results for Index 359: ['mehran'].
# Randomly found a city : Mehran.
# ------------
# Retrieving Results for Index 360: ['avera'].
# Randomly found a city : Avera.
# ------------
# Retrieving Results for Index 361: ['fort nelson'].
# Randomly found a city : Fort Nelson.
# ------------
# Retrieving Results for Index 362: ['urucara'].
# Randomly found a city : Urucara.
# ------------
# Retrieving Results for Index 363: ['makakilo city'].
# Randomly found a city : Makakilo City.
# ------------
# Retrieving Results for Index 364: ['dalbandin'].
# Randomly found a city : Dalbandin.
# ------------
# Retrieving Results for Index 365: ['cadillac'].
# Randomly found a city : Cadillac.
# ------------
# Retrieving Results for Index 366: ['atuona'].
# Randomly found a city : Atuona.
# ------------
# Retrieving Results for Index 367: ['changtu'].
# Randomly found a city : Changtu.
# ------------
# Retrieving Results for Index 368: ['zhanatas'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 369: ['cascais'].
# Randomly found a city : Cascais.
# ------------
# Retrieving Results for Index 370: ['dawson creek'].
# Randomly found a city : Dawson Creek.
# ------------
# Retrieving Results for Index 371: ['kissidougou'].
# Randomly found a city : Kissidougou.
# ------------
# Retrieving Results for Index 372: ['kruisfontein'].
# Randomly found a city : Kruisfontein.
# ------------
# Retrieving Results for Index 373: ['kirando'].
# Randomly found a city : Kirando.
# ------------
# Retrieving Results for Index 374: ['qaanaaq'].
# Randomly found a city : Qaanaaq.
# ------------
# Retrieving Results for Index 375: ['santa maria'].
# Randomly found a city : Santa Maria.
# ------------
# Retrieving Results for Index 376: ['tuktoyaktuk'].
# Randomly found a city : Tuktoyaktuk.
# ------------
# Retrieving Results for Index 377: ['atikokan'].
# Randomly found a city : Atikokan.
# ------------
# Retrieving Results for Index 378: ['punta arenas'].
# Randomly found a city : Punta Arenas.
# ------------
# Retrieving Results for Index 379: ['ekhabi'].
# Randomly found a city : Ekhabi.
# ------------
# Retrieving Results for Index 380: ['emerald'].
# Randomly found a city : Emerald.
# ------------
# Retrieving Results for Index 381: ['hanzhong'].
# Randomly found a city : Hanzhong.
# ------------
# Retrieving Results for Index 382: ['geresk'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 383: ['meulaboh'].
# Randomly found a city : Meulaboh.
# ------------
# Retrieving Results for Index 384: ['oyama'].
# Randomly found a city : Oyama.
# ------------
# Retrieving Results for Index 385: ['gulshat'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 386: ['nguru'].
# Randomly found a city : Nguru.
# ------------
# Retrieving Results for Index 387: ['aleysk'].
# Randomly found a city : Aleysk.
# ------------
# Retrieving Results for Index 388: ['raudeberg'].
# Randomly found a city : Raudeberg.
# ------------
# Retrieving Results for Index 389: ['mudgee'].
# Randomly found a city : Mudgee.
# ------------
# Retrieving Results for Index 390: ['landshut'].
# Randomly found a city : Landshut.
# ------------
# Retrieving Results for Index 391: ['madimba'].
# Randomly found a city : Madimba.
# ------------
# Retrieving Results for Index 392: ['mitsamiouli'].
# Randomly found a city : Mitsamiouli.
# ------------
# Retrieving Results for Index 393: ['mendeleyevo'].
# Randomly found a city : Mendeleyevo.
# ------------
# Retrieving Results for Index 394: ['manta'].
# Randomly found a city : Manta.
# ------------
# Retrieving Results for Index 395: ['chuy'].
# Randomly found a city : Chuy.
# ------------
# Retrieving Results for Index 396: ['beidao'].
# Randomly found a city : Beidao.
# ------------
# Retrieving Results for Index 397: ['baie-comeau'].
# Randomly found a city : Baie-Comeau.
# ------------
# Retrieving Results for Index 398: ['nguru'].
# Randomly found a city : Nguru.
# ------------
# Retrieving Results for Index 399: ['leningradskiy'].
# Randomly found a city : Leningradskiy.
# ------------
# Retrieving Results for Index 400: ['komatipoort'].
# Randomly found a city : Komatipoort.
# ------------
# Retrieving Results for Index 401: ['margate'].
# Randomly found a city : Margate.
# ------------
# Retrieving Results for Index 402: ['kamenka'].
# Randomly found a city : Kamenka.
# ------------
# Retrieving Results for Index 403: ['gilgit'].
# Randomly found a city : Gilgit.
# ------------
# Retrieving Results for Index 404: ['mandurah'].
# Randomly found a city : Mandurah.
# ------------
# Retrieving Results for Index 405: ['saravan'].
# Randomly found a city : Saravan.
# ------------
# Retrieving Results for Index 406: ['chokurdakh'].
# Randomly found a city : Chokurdakh.
# ------------
# Retrieving Results for Index 407: ['manicore'].
# Randomly found a city : Manicore.
# ------------
# Retrieving Results for Index 408: ['masterton'].
# Randomly found a city : Masterton.
# ------------
# Retrieving Results for Index 409: ['sao miguel do araguaia'].
# Randomly found a city : Sao Miguel do Araguaia.
# ------------
# Retrieving Results for Index 410: ['balaipungut'].
# Randomly found a city : Balaipungut.
# ------------
# Retrieving Results for Index 411: ['bambous virieux'].
# Randomly found a city : Bambous Virieux.
# ------------
# Retrieving Results for Index 412: ['bengkulu'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 413: ['iracoubo'].
# Randomly found a city : Iracoubo.
# ------------
# Retrieving Results for Index 414: ['saint-philippe'].
# Randomly found a city : Saint-Philippe.
# ------------
# Retrieving Results for Index 415: ['baruun-urt'].
# Randomly found a city : Baruun-Urt.
# ------------
# Retrieving Results for Index 416: ['baghdad'].
# Randomly found a city : Baghdad.
# ------------
# Retrieving Results for Index 417: ['luau'].
# Randomly found a city : Luau.
# ------------
# Retrieving Results for Index 418: ['trincomalee'].
# Randomly found a city : Trincomalee.
# ------------
# Retrieving Results for Index 419: ['posse'].
# Randomly found a city : Posse.
# ------------
# Retrieving Results for Index 420: ['mormugao'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 421: ['sao miguel do araguaia'].
# Randomly found a city : Sao Miguel do Araguaia.
# ------------
# Retrieving Results for Index 422: ['canico'].
# Randomly found a city : Canico.
# ------------
# Retrieving Results for Index 423: ['tiksi'].
# Randomly found a city : Tiksi.
# ------------
# Retrieving Results for Index 424: ['atikokan'].
# Randomly found a city : Atikokan.
# ------------
# Retrieving Results for Index 425: ['balaipungut'].
# Randomly found a city : Balaipungut.
# ------------
# Retrieving Results for Index 426: ['qixingtai'].
# Randomly found a city : Qixingtai.
# ------------
# Retrieving Results for Index 427: ['preobrazheniye'].
# Randomly found a city : Preobrazheniye.
# ------------
# Retrieving Results for Index 428: ['whitianga'].
# Randomly found a city : Whitianga.
# ------------
# Retrieving Results for Index 429: ['irbeyskoye'].
# Randomly found a city : Irbeyskoye.
# ------------
# Retrieving Results for Index 430: ['meulaboh'].
# Randomly found a city : Meulaboh.
# ------------
# Retrieving Results for Index 431: ['gornopravdinsk'].
# Randomly found a city : Gornopravdinsk.
# ------------
# Retrieving Results for Index 432: ['mount gambier'].
# Randomly found a city : Mount Gambier.
# ------------
# Retrieving Results for Index 433: ['aykhal'].
# Randomly found a city : Aykhal.
# ------------
# Retrieving Results for Index 434: ['kahului'].
# Randomly found a city : Kahului.
# ------------
# Retrieving Results for Index 435: ['yulara'].
# Randomly found a city : Yulara.
# ------------
# Retrieving Results for Index 436: ['geraldton'].
# Randomly found a city : Geraldton.
# ------------
# Retrieving Results for Index 437: ['port alfred'].
# Randomly found a city : Port Alfred.
# ------------
# Retrieving Results for Index 438: ['san carlos de bariloche'].
# Randomly found a city : San Carlos de Bariloche.
# ------------
# Retrieving Results for Index 439: ['wattegama'].
# Randomly found a city : Wattegama.
# ------------
# Retrieving Results for Index 440: ['hay river'].
# Randomly found a city : Hay River.
# ------------
# Retrieving Results for Index 441: ['taoudenni'].
# Randomly found a city : Taoudenni.
# ------------
# Retrieving Results for Index 442: ['shache'].
# Randomly found a city : Shache.
# ------------
# Retrieving Results for Index 443: ['changping'].
# Randomly found a city : Changping.
# ------------
# Retrieving Results for Index 444: ['beringovskiy'].
# Randomly found a city : Beringovskiy.
# ------------
# Retrieving Results for Index 445: ['te anau'].
# Randomly found a city : Te Anau.
# ------------
# Retrieving Results for Index 446: ['taungdwingyi'].
# Randomly found a city : Taungdwingyi.
# ------------
# Retrieving Results for Index 447: ['tezu'].
# Randomly found a city : Tezu.
# ------------
# Retrieving Results for Index 448: ['male'].
# Randomly found a city : Male.
# ------------
# Retrieving Results for Index 449: ['fayaoue'].
# Randomly found a city : Fayaoue.
# ------------
# Retrieving Results for Index 450: ['kununurra'].
# Randomly found a city : Kununurra.
# ------------
# Retrieving Results for Index 451: ['hanzhong'].
# Randomly found a city : Hanzhong.
# ------------
# Retrieving Results for Index 452: ['cockburn town'].
# Randomly found a city : Cockburn Town.
# ------------
# Retrieving Results for Index 453: ['tanete'].
# Randomly found a city : Tanete.
# ------------
# Retrieving Results for Index 454: ['barra patuca'].
# Randomly found a city : Barra Patuca.
# ------------
# Retrieving Results for Index 455: ['bonavista'].
# Randomly found a city : Bonavista.
# ------------
# Retrieving Results for Index 456: ['springfield'].
# Randomly found a city : Springfield.
# ------------
# Retrieving Results for Index 457: ['zavoronezhskoye'].
# Randomly found a city : Zavoronezhskoye.
# ------------
# Retrieving Results for Index 458: ['sungairaya'].
# Randomly found a city : Sungairaya.
# ------------
# Retrieving Results for Index 459: ['ponta delgada'].
# Randomly found a city : Ponta Delgada.
# ------------
# Retrieving Results for Index 460: ['paka'].
# Randomly found a city : Paka.
# ------------
# Retrieving Results for Index 461: ['palmer'].
# Randomly found a city : Palmer.
# ------------
# Retrieving Results for Index 462: ['garowe'].
# Randomly found a city : Garowe.
# ------------
# Retrieving Results for Index 463: ['abakaliki'].
# Randomly found a city : Abakaliki.
# ------------
# Retrieving Results for Index 464: ['ancud'].
# Randomly found a city : Ancud.
# ------------
# Retrieving Results for Index 465: ['hanzhong'].
# Randomly found a city : Hanzhong.
# ------------
# Retrieving Results for Index 466: ['cherskiy'].
# Randomly found a city : Cherskiy.
# ------------
# Retrieving Results for Index 467: ['kardymovo'].
# Randomly found a city : Kardymovo.
# ------------
# Retrieving Results for Index 468: ['kirksville'].
# Randomly found a city : Kirksville.
# ------------
# Retrieving Results for Index 469: ['clyde river'].
# Randomly found a city : Clyde River.
# ------------
# Retrieving Results for Index 470: ['martyush'].
# Randomly found a city : Martyush.
# ------------
# Retrieving Results for Index 471: ['sitka'].
# Randomly found a city : Sitka.
# ------------
# Retrieving Results for Index 472: ['haines junction'].
# Randomly found a city : Haines Junction.
# ------------
# Retrieving Results for Index 473: ['darnah'].
# Randomly found a city : Darnah.
# ------------
# Retrieving Results for Index 474: ['provideniya'].
# Randomly found a city : Provideniya.
# ------------
# Retrieving Results for Index 475: ['auki'].
# Randomly found a city : Auki.
# ------------
# Retrieving Results for Index 476: ['marsh harbour'].
# Randomly found a city : Marsh Harbour.
# ------------
# Retrieving Results for Index 477: ['bokspits'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 478: ['mawlaik'].
# Randomly found a city : Mawlaik.
# ------------
# Retrieving Results for Index 479: ['emerald'].
# Randomly found a city : Emerald.
# ------------
# Retrieving Results for Index 480: ['port alfred'].
# Randomly found a city : Port Alfred.
# ------------
# Retrieving Results for Index 481: ['ciechocinek'].
# Randomly found a city : Ciechocinek.
# ------------
# Retrieving Results for Index 482: ['belushya guba'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 483: ['ambon'].
# Randomly found a city : Ambon.
# ------------
# Retrieving Results for Index 484: ['balkanabat'].
# Randomly found a city : Balkanabat.
# ------------
# Retrieving Results for Index 485: ['ulladulla'].
# Randomly found a city : Ulladulla.
# ------------
# Retrieving Results for Index 486: ['zanjan'].
# Randomly found a city : Zanjan.
# ------------
# Retrieving Results for Index 487: ['amahai'].
# Randomly found a city : Amahai.
# ------------
# Retrieving Results for Index 488: ['huatulco'].
# Randomly found a city : Huatulco.
# ------------
# Retrieving Results for Index 489: ['cherskiy'].
# Randomly found a city : Cherskiy.
# ------------
# Retrieving Results for Index 490: ['lima'].
# Randomly found a city : Lima.
# ------------
# Retrieving Results for Index 491: ['susangerd'].
# Randomly found a city : Susangerd.
# ------------
# Retrieving Results for Index 492: ['trincomalee'].
# Randomly found a city : Trincomalee.
# ------------
# Retrieving Results for Index 493: ['cherskiy'].
# Randomly found a city : Cherskiy.
# ------------
# Retrieving Results for Index 494: ['ust-tsilma'].
# Randomly found a city : Ust-Tsilma.
# ------------
# Retrieving Results for Index 495: ['mys shmidta'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 496: ['aksarka'].
# Randomly found a city : Aksarka.
# ------------
# Retrieving Results for Index 497: ['manta'].
# Randomly found a city : Manta.
# ------------
# Retrieving Results for Index 498: ['prachuap khiri khan'].
# Randomly found a city : Prachuap Khiri Khan.
# ------------
# Retrieving Results for Index 499: ['maragogi'].
# Randomly found a city : Maragogi.
# ------------
# Retrieving Results for Index 500: ['ballina'].
# Randomly found a city : Ballina.
# ------------
# Retrieving Results for Index 501: ['dwarka'].
# Randomly found a city : Dwarka.
# ------------
# Retrieving Results for Index 502: ['kununurra'].
# Randomly found a city : Kununurra.
# ------------
# Retrieving Results for Index 503: ['maghama'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 504: ['trincomalee'].
# Randomly found a city : Trincomalee.
# ------------
# Retrieving Results for Index 505: ['durres'].
# Randomly found a city : Durres.
# ------------
# Retrieving Results for Index 506: ['saint-pierre'].
# Randomly found a city : Saint-Pierre.
# ------------
# Retrieving Results for Index 507: ['asfi'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 508: ['khokhlovo'].
# Randomly found a city : Khokhlovo.
# ------------
# Retrieving Results for Index 509: ['kargopol'].
# Randomly found a city : Kargopol.
# ------------
# Retrieving Results for Index 510: ['pangnirtung'].
# Randomly found a city : Pangnirtung.
# ------------
# Retrieving Results for Index 511: ['galeana'].
# Randomly found a city : Galeana.
# ------------
# Retrieving Results for Index 512: ['kakuda'].
# Randomly found a city : Kakuda.
# ------------
# Retrieving Results for Index 513: ['cherskiy'].
# Randomly found a city : Cherskiy.
# ------------
# Retrieving Results for Index 514: ['lagoa'].
# Randomly found a city : Lagoa.
# ------------
# Retrieving Results for Index 515: ['mitsamiouli'].
# Randomly found a city : Mitsamiouli.
# ------------
# Retrieving Results for Index 516: ['juneau'].
# Randomly found a city : Juneau.
# ------------
# Retrieving Results for Index 517: ['vila franca do campo'].
# Randomly found a city : Vila Franca do Campo.
# ------------
# Retrieving Results for Index 518: ['ati'].
# Randomly found a city : Ati.
# ------------
# Retrieving Results for Index 519: ['quevedo'].
# Randomly found a city : Quevedo.
# ------------
# Retrieving Results for Index 520: ['necochea'].
# Randomly found a city : Necochea.
# ------------
# Retrieving Results for Index 521: ['green river'].
# Randomly found a city : Green River.
# ------------
# Retrieving Results for Index 522: ['byron bay'].
# Randomly found a city : Byron Bay.
# ------------
# Retrieving Results for Index 523: ['cherskiy'].
# Randomly found a city : Cherskiy.
# ------------
# Retrieving Results for Index 524: ['batak'].
# Randomly found a city : Batak.
# ------------
# Retrieving Results for Index 525: ['rundu'].
# Randomly found a city : Rundu.
# ------------
# Retrieving Results for Index 526: ['landshut'].
# Randomly found a city : Landshut.
# ------------
# Retrieving Results for Index 527: ['ballina'].
# Randomly found a city : Ballina.
# ------------
# Retrieving Results for Index 528: ['havelock'].
# Randomly found a city : Havelock.
# ------------
# Retrieving Results for Index 529: ['oum hadjer'].
# Randomly found a city : Oum Hadjer.
# ------------
# Retrieving Results for Index 530: ['dikson'].
# Randomly found a city : Dikson.
# ------------
# Retrieving Results for Index 531: ['talas'].
# Randomly found a city : Talas.
# ------------
# Retrieving Results for Index 532: ['chuy'].
# Randomly found a city : Chuy.
# ------------
# Retrieving Results for Index 533: ['alofi'].
# Randomly found a city : Alofi.
# ------------
# Retrieving Results for Index 534: ['sao miguel do araguaia'].
# Randomly found a city : Sao Miguel do Araguaia.
# ------------
# Retrieving Results for Index 535: ['falam'].
# Randomly found a city : Falam.
# ------------
# Retrieving Results for Index 536: ['zhoucun'].
# Randomly found a city : Zhoucun.
# ------------
# Retrieving Results for Index 537: ['hay river'].
# Randomly found a city : Hay River.
# ------------
# Retrieving Results for Index 538: ['longonjo'].
# Randomly found a city : Longonjo.
# ------------
# Retrieving Results for Index 539: ['witu'].
# Randomly found a city : Witu.
# ------------
# Retrieving Results for Index 540: ['privolnaya'].
# Randomly found a city : Privolnaya.
# ------------
# Retrieving Results for Index 541: ['cartagena'].
# Randomly found a city : Cartagena.
# ------------
# Retrieving Results for Index 542: ['mugur-aksy'].
# Randomly found a city : Mugur-Aksy.
# ------------
# Retrieving Results for Index 543: ['qaanaaq'].
# Randomly found a city : Qaanaaq.
# ------------
# Retrieving Results for Index 544: ['riyadh'].
# Randomly found a city : Riyadh.
# ------------
# Retrieving Results for Index 545: ['sault sainte marie'].
# Randomly found a city : Sault Sainte Marie.
# ------------
# Retrieving Results for Index 546: ['mount gambier'].
# Randomly found a city : Mount Gambier.
# ------------
# Retrieving Results for Index 547: ['cockburn town'].
# Randomly found a city : Cockburn Town.
# ------------
# Retrieving Results for Index 548: ['mugur-aksy'].
# Randomly found a city : Mugur-Aksy.
# ------------
# Retrieving Results for Index 549: ['green river'].
# Randomly found a city : Green River.
# ------------
# Retrieving Results for Index 550: ['yeppoon'].
# Randomly found a city : Yeppoon.
# ------------
# Retrieving Results for Index 551: ['baruun-urt'].
# Randomly found a city : Baruun-Urt.
# ------------
# Retrieving Results for Index 552: ['ushuaia'].
# Randomly found a city : Ushuaia.
# ------------
# Retrieving Results for Index 553: ['oyama'].
# Randomly found a city : Oyama.
# ------------
# Retrieving Results for Index 554: ['kuliyapitiya'].
# Randomly found a city : Kuliyapitiya.
# ------------
# Retrieving Results for Index 555: ['le mars'].
# Randomly found a city : Le Mars.
# ------------
# Retrieving Results for Index 556: ['ekhabi'].
# Randomly found a city : Ekhabi.
# ------------
# Retrieving Results for Index 557: ['oriximina'].
# Randomly found a city : Oriximina.
# ------------
# Retrieving Results for Index 558: ['jackson'].
# Randomly found a city : Jackson.
# ------------
# Retrieving Results for Index 559: ['kuliyapitiya'].
# Randomly found a city : Kuliyapitiya.
# ------------
# Retrieving Results for Index 560: ['te anau'].
# Randomly found a city : Te Anau.
# ------------
# Retrieving Results for Index 561: ['pochutla'].
# Randomly found a city : Pochutla.
# ------------
# Retrieving Results for Index 562: ['taungdwingyi'].
# Randomly found a city : Taungdwingyi.
# ------------
# Retrieving Results for Index 563: ['trincomalee'].
# Randomly found a city : Trincomalee.
# ------------
# Retrieving Results for Index 564: ['anadyr'].
# Randomly found a city : Anadyr.
# ------------
# Retrieving Results for Index 565: ['frontera'].
# Randomly found a city : Frontera.
# ------------
# Retrieving Results for Index 566: ['pisco'].
# Randomly found a city : Pisco.
# ------------
# Retrieving Results for Index 567: ['killarney'].
# Randomly found a city : Killarney.
# ------------
# Retrieving Results for Index 568: ['xihua'].
# Randomly found a city : Xihua.
# ------------
# Retrieving Results for Index 569: ['hirado'].
# Randomly found a city : Hirado.
# ------------
# Retrieving Results for Index 570: ['nsanje'].
# Randomly found a city : Nsanje.
# ------------
# Retrieving Results for Index 571: ['neryungri'].
# Randomly found a city : Neryungri.
# ------------
# Retrieving Results for Index 572: ['mazamari'].
# Randomly found a city : Mazamari.
# ------------
# Retrieving Results for Index 573: ['landshut'].
# Randomly found a city : Landshut.
# ------------
# Retrieving Results for Index 574: ['whitianga'].
# Randomly found a city : Whitianga.
# ------------
# Retrieving Results for Index 575: ['longyearbyen'].
# Randomly found a city : Longyearbyen.
# ------------
# Retrieving Results for Index 576: ['kamenka'].
# Randomly found a city : Kamenka.
# ------------
# Retrieving Results for Index 577: ['arlit'].
# Randomly found a city : Arlit.
# ------------
# Retrieving Results for Index 578: ['la paz'].
# Randomly found a city : La Paz.
# ------------
# Retrieving Results for Index 579: ['hasaki'].
# Randomly found a city : Hasaki.
# ------------
# Retrieving Results for Index 580: ['kamenskoye'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 581: ['barentsburg'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 582: ['boden'].
# Randomly found a city : Boden.
# ------------
# Retrieving Results for Index 583: ['atambua'].
# Randomly found a city : Atambua.
# ------------
# Retrieving Results for Index 584: ['khandyga'].
# Randomly found a city : Khandyga.
# ------------
# Retrieving Results for Index 585: ['saravan'].
# Randomly found a city : Saravan.
# ------------
# Retrieving Results for Index 586: ['huatulco'].
# Randomly found a city : Huatulco.
# ------------
# Retrieving Results for Index 587: ['safford'].
# Randomly found a city : Safford.
# ------------
# Retrieving Results for Index 588: ['virginia beach'].
# Randomly found a city : Virginia Beach.
# ------------
# Retrieving Results for Index 589: ['virginia beach'].
# Randomly found a city : Virginia Beach.
# ------------
# Retrieving Results for Index 590: ['kimberley'].
# Randomly found a city : Kimberley.
# ------------
# Retrieving Results for Index 591: ['necochea'].
# Randomly found a city : Necochea.
# ------------
# Retrieving Results for Index 592: ['lorengau'].
# Randomly found a city : Lorengau.
# ------------
# Retrieving Results for Index 593: ['opuwo'].
# Randomly found a city : Opuwo.
# ------------
# Retrieving Results for Index 594: ['ginda'].
# Randomly found a city : Ginda.
# ------------
# Retrieving Results for Index 595: ['ossora'].
# Randomly found a city : Ossora.
# ------------
# Retrieving Results for Index 596: ['balkanabat'].
# Randomly found a city : Balkanabat.
# ------------
# Retrieving Results for Index 597: ['puerto madero'].
# Randomly found a city : Puerto Madero.
# ------------
# Retrieving Results for Index 598: ['great malvern'].
# Randomly found a city : Great Malvern.
# ------------
# Retrieving Results for Index 599: ['soyo'].
# Randomly found a city : Soyo.
# ------------
# Retrieving Results for Index 600: ['labuhan'].
# Randomly found a city : Labuhan.
# ------------
# Retrieving Results for Index 601: ['kamenka'].
# Randomly found a city : Kamenka.
# ------------
# Retrieving Results for Index 602: ['rundu'].
# Randomly found a city : Rundu.
# ------------
# Retrieving Results for Index 603: ['balaipungut'].
# Randomly found a city : Balaipungut.
# ------------
# Retrieving Results for Index 604: ['dicabisagan'].
# Randomly found a city : Dicabisagan.
# ------------
# Retrieving Results for Index 605: ['taolanaro'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 606: ['susangerd'].
# Randomly found a city : Susangerd.
# ------------
# Retrieving Results for Index 607: ['mar del plata'].
# Randomly found a city : Mar del Plata.
# ------------
# Retrieving Results for Index 608: ['broome'].
# Randomly found a city : Broome.
# ------------
# Retrieving Results for Index 609: ['whitehorse'].
# Randomly found a city : Whitehorse.
# ------------
# Retrieving Results for Index 610: ['vila franca do campo'].
# Randomly found a city : Vila Franca do Campo.
# ------------
# Retrieving Results for Index 611: ['wampusirpi'].
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 612: ['mnogovershinnyy'].
# Randomly found a city : Mnogovershinnyy.
# ------------
# Retrieving Results for Index 613: ['volkhov'].
# Randomly found a city : Volkhov.
# ------------
# Retrieving Results for Index 614: ['privolnaya'].
# Randomly found a city : Privolnaya.
# ------------
# Retrieving Results for Index 615: ['mar del plata'].
# Randomly found a city : Mar del Plata.
# ------------
# Retrieving Results for Index 616: ['rio grande'].
# Randomly found a city : Rio Grande.
# ------------
# Retrieving Results for Index 617: ['privolnaya'].
# Randomly found a city : Privolnaya.
# ------------
# Retrieving Results for Index 618: ['vila velha'].
# Randomly found a city : Vila Velha.
# ------------
# Retrieving Results for Index 619: ['midland'].
# Randomly found a city : Midland.
# ------------
# Retrieving Results for Index 620: ['susangerd'].
# Randomly found a city : Susangerd.
# ------------
# Retrieving Results for Index 621: ['mount gambier'].
# Randomly found a city : Mount Gambier.
# ------------
# Retrieving Results for Index 622: ['rio gallegos'].
# Randomly found a city : Rio Gallegos.
# ------------
# Retrieving Results for Index 623: ['castro'].
# Randomly found a city : Castro.
# ------------
# Retrieving Results for Index 624: ['husavik'].
# Randomly found a city : Husavik.
# ------------
# Retrieving Results for Index 625: ['bad voslau'].
# Randomly found a city : Bad Voslau.
# ------------

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather"
params = {
    "q": cities[1],
    "APPID": api_key,
}

request = requests.get(base_url, params).json()

print(json.dumps(request, indent=4))
# Out:
# {
#     "coord": {
#         "lon": -73.48,
#         "lat": 45.36
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 283.97,
#         "pressure": 1017,
#         "humidity": 66,
#         "temp_min": 282.59,
#         "temp_max": 285.37
#     },
#     "visibility": 16093,
#     "wind": {
#         "speed": 2.6,
#         "deg": 30
#     },
#     "clouds": {
#         "all": 40
#     },
#     "dt": 1570053170,
#     "sys": {
#         "type": 1,
#         "id": 4146,
#         "message": 0.0068,
#         "country": "CA",
#         "sunrise": 1570013572,
#         "sunset": 1570055617
#     },
#     "timezone": -14400,
#     "id": 6138908,
#     "name": "Saint-Philippe",
#     "cod": 200
# }

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv(output_data_file)
cities_df.head()
# Out:
#                   City Cloudiness Country Humidity    Lat     Lon Max Temp  \
# 0              Iqaluit         75      CA       86  63.75  -68.52   276.15
# 1                Ginda          0      IN       81  30.69   78.49  283.177
# 2             Bembibre         64      ES       81  42.62   -6.42   285.93
# 3               Aykhal         75      RU      100  65.95  111.51   267.15
# 4  Prachuap Khiri Khan         96      TH       98  11.81   99.79  295.177
#
#   Wind Speed
# 0        5.1
# 1       1.76
# 2        2.1
# 3          2
# 4       0.91

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(cities_df['Lat'], cities_df['Max Temp'])
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (K)')
plt.title('Latitude vs. Temperature (10/02/19)')
# Out:
# Text(0.5, 1.0, 'Latitude vs. Temperature (10/02/19)')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cities_df['Lat'], cities_df['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Latitude vs. Humidity (10/02/19)')
# Out:
# Text(0.5, 1.0, 'Latitude vs. Humidity (10/02/19)')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_df['Lat'], cities_df['Max Temp'])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('Latitude vs. Cloudiness (10/02/19)')
# Out:
# Text(0.5, 1.0, 'Latitude vs. Cloudiness (10/02/19)')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_df['Lat'], cities_df['Wind Speed'])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Latitude vs. Wind Speed (10/02/19)')
# Out:
# Text(0.5, 1.0, 'Latitude vs. Wind Speed (10/02/19)')
